# %% [markdown]
# # Overview:
#
# While looking for web based UIs to support LangChain I came accross LangFlow.

# %% [markdown]
# # Installation

# %% [markdown]
# According to the official installation instructions, the LangFlow solution is packaged as a python module and can be installed via pip. So with that

# %% [markdown]
# This installed the latest stable release
#
# ```
# (langflow-3.10) [root@fedora ~]# pip list | grep langflow
# langflow                                 0.6.15
# ```

# %% [markdown]
# I ran the application with a special instruction so that it binded to all IPs

# %% [markdown]
# The page failed to load
