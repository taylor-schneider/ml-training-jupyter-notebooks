# %% [markdown]
# # Overview

# %% [markdown]
# In this notebook we will review sigmoid functions.

# %% [markdown]
# In general, This family of functions take on an S-shape which is monotonically increasing. That being said, in general, we can parameterize these functions to take on a "reverse S-shape".

# %% [markdown]
# # Etymology

# %% [markdown]
# Sigmoid, or sigmoidal functions, derive their name from the greek letter Sigma. The letter takes on a third form (as opposed to the normal two cases: upper and lowercase) when occurring at the end of a word. The form is written $\varsigma$ and over time has been written as either a C-like shape or an S-like shape. Additionally Sigma is equivalent, or translates into, to the letter S in the latin alphabet (which english uses).
#
# Because of the physical characteristics of the letter (being S-shaped), it is used to describe curves which exhibit the same properties. Specificially S-shaped curves.

# %% [markdown]
# # Logistic Function

# %% [markdown]
# ## Overview
#
# The logistic function is a function within the sigmoid family, meaning that it takes on an S-shape which is monotonically increasing. That being said, we can parameterize the function to take on a "reverse S-shape". Additionally the function has several notable properties which we will discuss including the fact that is is symmetric.

# %% [markdown]
# #### Definition

# %% [markdown]
# The function is typically given as either a differential or its analytical solution:
#
# $$ \frac{dp}{dt} = a p\left(1-\frac{p}{k} \right) $$
#
# $$ p(t) = \frac{k}{1+be^{-at}}, \ \ \ where \ \ b=\frac{k-p_0}{p_0} $$

# %% [markdown]
# Where
# - $a$ is the growth rate which impacts the steepness of the curve
# - $k$ is the maximum value of the curve
# - $p_0$ is the value $p(t=0)$.

# %% [markdown]
# **Note**: There are a few other formulas which also characterize the logistic function; while they look different, their graphs are identical thus they are analytically equivalent even if no direct algebraic derevation/conversion between the formulas exists.

# %% [markdown]
# For proofs of the derevations see the derevation section which references lectures from [Northwestern University](https://mlerma54.github.io/courses/math214-2-03f/notes/c2-logist.pdf) and [Clark University](https://www2.clarku.edu/faculty/djoyce/ma121/logistic.pdf).

# %% [markdown]
# In more general cases, where we are not dealing with time, and the initial independent variable, lets use $x$, is not equal to zero, we would expand the equation by replacing the constant $a$ with the expression $x-x_0$:
#
# $$ p(x) = \frac{k}{1+be^{-a(x-x_0)}}$$

# %% [markdown]
# But the derivative of this function is quite messy, so normalizing $x$ so that it behaves like $t$ would be preferential.

# %% [markdown]
# ## Etymology

# %% [markdown]
# Verhulst originally published the logistic function in a paper written in his native French language. As such, he referred to the function as "logistique". The term logistic is an english translation of that term. Additionally, Verhulst did not provide an explanation, in his publication or otherwise, for why he chose the term. Below is a speculation that seems to be widely accepted; or atleast proposed as an infferential reasioning as to the word choice.
#
# I believe we do get some insights an intuition from the arguments and discussion that Verhulst provides in his paper while arguing that the logistic curve better models population growth as compared to the logarithmic curve. I believe the chioce of terminology is ultimately made to characterize the curves according to their underlying philosophical beliefs.
#
# Verhulst begins by discussing different models for population growth. He puts forward a number of equations which arethmetically appear exponential; for example one takes the form $p=k10^{lt}$ where p is the population, k and l are constants, and t represents time. During this section he discusses geometric growth rates, and he qualifies the population models as being logarithmic because they have similar characteristics to logarithmic functions; they start at the origin (denoting zero population at  the initial point in time) and have no maximum value.
#
# **Note**: I've seen some some confusion in various posts about this section and the implications of the use of the qualifier logarithmic. I believe many misunderstood or mistranslated the section and took it to mean that Verhulst was referring to these geometric and/or exponential forms as being THE logarithmic function, rather than just exhibiting properties of a logarithmic function.
#
# He also criticizes these models because they do not model any forces that would put downward pressure on the growth rate or limit them with a horizontal asymtote.
#
# [Kingsland (1982)](https://u.demog.berkeley.edu/~jrw/Biblio/Eprints/%20J-L/kingsland.1982_logistic.curve.pdf) states:
#
# > in the nineteenth century the
# French word was used to signify the art of
# calculation, as opposed to a branch of theoretical arithmetic such as the theory of proportion. It was commonly applied to a type
# of logarithm used in making astronomical
# calculations. Verhulst probably intended this
# term to convey the idea of a calculating
# device, from which one could determine the
# saturation level of the population and the
# time when it would reach that value.
#
# Additionally I believe we can gain some intuition by looking at the etymology of the term logarithm:
#
# > a mathematical function used to shorten calculation, 1610s, logarithmus, coined in Modern Latin by Scottish mathematician John Napier (1550-1617), literally "ratio-number," from Greek logos "proportion, ratio, word" (see Logos) + arithmos "number" (from PIE *erei-dhmo-, suffixed variant form of root *re- "to reason, count"). Napier invented them and published a table in 1614; the kind now chiefly in use were invented by his contemporary Henry Briggs (1561-1630), a professor of geometry at Gresham College, London.
# >
# > [online etymology dictionary](https://www.etymonline.com/word/logarithm)
# >
# > The term logarithm is itself derived as log-arithm, from Ancient Greek λόγος (lógos) and ἀριθμός (arithmós)
# >
# > [stackexchange](https://math.stackexchange.com/questions/357918/why-is-logistic-equation-called-logistic)
#
# As noted [on stackexchange](https://stats.stackexchange.com/questions/192948/why-is-the-logistic-distribution-called-logistic), I belive that Verhulst uses a different term because he wants to highlight the disctinction of a horizontal asymtote, or atleast downward pressure, being a logical requirement for a population model. The term logistic seems to imply that this new curve was logically selected and still has the same roots in logical arithmetic
#
# > "pertaining to logic," 1620s, from Medieval Latin logisticus, from Greek logistikos "skilled in calculating; endued with reason," from logistes "a calculator," from logos "calculation, proportion" (see Logos). Related: Logistical (1560s); logistically. Logistics, from this word, in the sense "art of arithmetical calculation" is from 1650s.
# >
# > [online etymology dictionary](https://www.etymonline.com/word/logistic)
#
# **Note**: I have seen claims that *"In the 1700's, logarithmic and logistic were synonymous."* However these claims came without sources or proof of any kind and this was almost 100 years prior to the publication.

# %% [markdown]
# In his paper, Verhulst gives the following diagram which I believe aligns with the inferences above:
#
# <center><img src="./images/logarithmic_vs_logistic.png" style="width:500px"></center>

# %% [markdown]
# ## History

# %% [markdown]
# Cramer provides several publications on the origins and derevation of the logistic function. They seem to be a successive refinement of the historical recount and in some cases do each present unique insights.
#
# 1. [Carmer (2002) - The Origins Of Logistic Regression](https://papers.tinbergen.nl/02119.pdf)
# 3. [Cramer (2003) - Logit Models From Economics and Other Fields (Chapter 9)](https://lunarintcollege.edu.et/wp-content/uploads/2022/07/J.S.Cramer-Logit-Models-from-Economics-and-Other-Fields.pdf)

# %% [markdown]
# ### Malthus (1789) - Unopposed Population Growth

# %% [markdown]
# ### Quetelet (1835) - Constrained Population Growth
#
# In 1835, Qeutelet [published](https://gallica.bnf.fr/ark:/12148/bpt6k81570d/f6.item.r=.langFR) *Sur I'homme et le developpement de ses facultes; ou Essai de physique sociale* in his native french, which roughtly translates into *On Man and the development of his faculties; an essay of social dynamics*. An english translation titled *A Treatise on Man and the Development of His Faculties* was [published](https://onlinelibrary.wiley.com/doi/10.1002/j.1550-8528.1994.tb00047.x) in 1994.

# %% [markdown]
# [Kingsland (1982)](https://u.demog.berkeley.edu/~jrw/Biblio/Eprints/%20J-L/kingsland.1982_logistic.curve.pdf) states:
#
# > Quetelet had proposed in
# 1835 that the resistance to the growth of a
# population was proportional to the square of
# the speed with which the population increased.
# He found this relation appealing because he
# saw in it a direct physical analogy to the resistance that a medium opposes to a body
# travelling through it... He suggested that Verhulst submit the
# principle to examination and apply it to
# whatever population data were available.

# %% [markdown]
# As [Bacaer (2011)](https://webpages.ciencias.ulisboa.pt/~mcgomes/aulas/dinpop/Mod13/Verhulst.pdf) adds:
#
# > That same year 1835, his compatriot Adolphe Quetelet, a statistician and director
# of the observatory in Brussels, published A Treatise on Man and the Development of
# his Faculties. Quetelet suggested that populations could not grow geometrically over
# a long period of time because the obstacles mentioned by Malthus formed a kind of
# “resistance”, which he thought (by analogy with mechanics) was proportional to
# the square of the speed of population growth. This analogy had no real basis, but it
# inspired Verhulst.

# %% [markdown]
# ### Verhulst (1838) - Population Growth With Upper Limit
#
# Verhulst [publishes](https://userpages.umbc.edu/~rostamia/math481/1838-Verhulst.pdf) the first argument for constrained population growth in a four page paper titled *Notice sur la loi que la population suit dans son accroissement*. This loosely translates to *Note on the law of population growth*. This was published in the french publication, *Correspondance mathématique et physique* journal, which translates to the Journal of Math and Physics. A full [english translation](https://www.neo-classical-physics.info/uploads/3/4/3/6/34363841/verhulst_-_law_of_population.pdf) is provided by Delphenich.

# %% [markdown]
# As [Bacaer (2011)](https://webpages.ciencias.ulisboa.pt/~mcgomes/aulas/dinpop/Mod13/Verhulst.pdf) provides a translated excerpt:
#
# > We know that the famous Malthus showed the principle that the human population tends to
# grow in a geometric progression so as to double after a certain period of time, for example
# every twenty five years. This proposition is beyond dispute if abstraction is made of the
# increasing difficulty to find food [. . . ]
# The virtual increase of the population is therefore limited by the size and the fertility of
# the country. As a result the population gets closer and closer to a steady state.

# %% [markdown]
# [Bacaer (2011)](https://webpages.ciencias.ulisboa.pt/~mcgomes/aulas/dinpop/Mod13/Verhulst.pdf) speculates the Verhulst did not completely agree with Quetelet; specifically taking issue with the mechanical nature of the analogy. This is not directly mentioned in Virhulst's first publication however.

# %% [markdown]
# [Kingsland (1982)](https://u.demog.berkeley.edu/~jrw/Biblio/Eprints/%20J-L/kingsland.1982_logistic.curve.pdf) states:
#
# > Verhulst began by reasoning that in the
# early states of growth, a population would
# increase exponentially until such time when
# crucial resources, in this case farmland,
# became limiting. He called the population
# existing at that moment the "normal" population: the number in excess beyond the normal population was called the "superabundant" population. Assuming that the rate of
# growth was retarded by some function
# linearly proportional to the size of the superabundant population, he obtained the differential equation for a symmetrical sigmoidal
# curve of growth, which he labelled the
# "logistic" (Verhulst, 1845). In fact, his line of
# reasoning did not correspond to the mathematics of his derivation of the curve: the
# logistic does not follow from the idea that
# growth shifts abruptly from an exponential
# rate to a slower "logistic" one at some crucial
# density. In any case, Verhulst realized that
# the logistic was only one possibility; the ob-stacles to growth could also be proportional
# to the square of the superabundant population, for example.

# %% [markdown]
# Reading through the translation by [Delphenich](https://www.neo-classical-physics.info/uploads/3/4/3/6/34363841/verhulst_-_law_of_population.pdf) we see:
#
# > One can make various hypotheses in the resistance or the sum of the obstacles that are
# opposed to the indefinite development of the population. Quetelet supposed that it was proportional to the square of the rate at which the population tends to grow.
# >
# > This equates the motion of the population to that of a moving body that falls while
# traversing a resistant medium. The results of that comparison agree in a satisfactory
# manner with the ones that are given by statistics and with the ones that I obtained from
# own formulas when I assumed that there is an indefinitely-increasing density in the layers
# of the medium being traversed.
#
# We see Verhulst reiterate that there must be an upper limit to growth (Delphenich):
#
# > The increase in the population necessarily has a limit that is defined by the ground
# area that is available for the housing of the population... All of the formulas by
# which one attempts to represent the law of population must then satisfy the condition that
# they admit a maximum that is attained only after an infinitely-extended epoch.

# %% [markdown]
# Verhulst then gives an equation the widely cited differential equation
#
# $$ \frac{dp}{dt} = mp - \phi(p) $$
#
# Where $p$ is population, $m$ is an arbitrary constant (interpreted as a growth rate), and $\phi$ is an unknown function of $p$  (interpreted as the downard pressure or decay rate).
#
# He notes that
#
# > If the population grows in a progression that is more than geometric then the term
# −ϕ(p) will become +ϕ(p).

# %% [markdown]
# Verhulst then gives several example functions for $\phi$ such as: $\phi(p) = np^2$, $\phi(p) = np^3$, $\phi(p) = np^4$, $\phi(p) = n \ log \ p$ where $n$ is an arbitrary constant.

# %% [markdown]
# He notes that they will produce similar values but different upper limits.
#
# He then compares actual populations with theoretical populations calculated using the proposed functions and notes that there is a similarity and shows that the error term is not growing. He does not specifically state which of these example functions he uses.

# %% [markdown]
# **Note**: Verhulst does not write the logistic equation as we know it today in this paper despite people citing it as the source. Below I will explain algebraically how to derive today's form; but this is not part of verhulsts paper.

# %% [markdown]
# If we expand the differential equation with $\phi(p) = np^2$ we will see
#
# $$ \frac{dp}{dt} = mp - np^2$$

# %% [markdown]
# And if we consider the arbitrary constant $n$ to be composed of additional arbitrary constants such that $n=\frac{m}{k}$ we see the classic form forthe derivative that is referenced today:
#
# $$ \frac{dp}{dt} = mp - \frac{mp^2}{k}$$
#
# $$ = mp(1 - \frac{p}{k})$$

# %% [markdown]
# **Note**: As we discuss later, this equation is mathematically equivalent to the equation produced by Reed and Pearl and thus the integral, i.e. the logistic function is the same function.

# %% [markdown]
# ### Verhulst (1844) - A follow up
#
# In 1844, Verhulst [published](http://www.med.mcgill.ca/epidemiology/hanley/anniversaries/ByTopic/Verhulst1844.pdf) *Recherches mathématiques sur la loi d'accroissement de la population*. Here he expands on his prior work from 1838.

# %% [markdown]
# He starts by talking about the geometric population, using a similar formula but different notation:
#
# $$ p = \Pi 10 ^ {lt} $$
#
# Where $p$ is again the population, $\Pi$ is the original population, and $l$ is an arbitrary constant and the growth rate.

# %% [markdown]
# In a lengthy discussion he tries to reverse-engineer changes into the equation; he looks at the first and second derivatives to understand if the conclusions being asserted by the equation's form are still valid.

# %% [markdown]
# After reading through the paper, there was nothing major in terms of the development of the logistic function. The form published in his prior work was an early variant of the form recognized today. The versions of the equations published in this paper, and later papers, only manipulate constants involved in the algebra of fitting the curve to the data and do not materially impact the mathematical form produced by the original equation.

# %% [markdown]
# ### Verhulst (1847) - An additional follow up

# %% [markdown]
# In January of 1847, Verhulst [published](https://lib.ugent.be/europeana/900000091028?pg=RA3-PA3) a follow up to his prior paper titled *Deuxième mémoire sur la loi d'accroissement de la population*.
#
# After reading through the paper, there was nothing major in terms of the development of the logistic function. The publication is quite long and I was unable to find a translation. I believe the paper serves to validate the equation as being able to fit emperical evidences.The form published in his prior work was an early variant of the form recognized today.

# %% [markdown]
# ### Robertson (1908) - Independent Use OF Quetelet's Data To Derive Sigmoid
#
# In 1908, Robertson published *On the normal rate of growth of an individual and its biochemical significance.*.
#
# [Kingsland (1982)](https://u.demog.berkeley.edu/~jrw/Biblio/Eprints/%20J-L/kingsland.1982_logistic.curve.pdf) states:
# > When Raymond Pearl and LowellJ. Reed
# (1920) introduced the same curve in 1920,
# however, they were wholly unaware of Verhulst's memoirs. The true precursor in this
# case was not Verhulst, but the physiologist
# T. B. Robertson, who in 1908 had published
# two articles applying the same sigmoidal
# curve to various cases of individual growth
# in animals, plants, and man. By coincidence, he used some of Quetelet's data,
# without apparently being aware of Quetelet's
# population interests or of Verhulst's
# memoirs. Robertson called his curve the
# "autocatalytic" or self-accelerating curve,
# because it was the same as that used to
# describe certain chemical reactions, in which
# one of the products of the change had the
# property of accelerating the further progress
# of the reaction. On the basis of this similarity
# between chemical and growth curves,
# Robertson constructed an elaborate hypothesis to explain the changes observed in the
# rate of growth of individuals. He postulated
# that growth itself was an autocatalytic phenomenon, controlled by the secretion of an
# unknown catalyst, which would act to stimulate growth. The original theory applied only
# to the growth rate in individual organisms,
# but was later extended to cover growth in
# protozoan and bacterial populations
# (Robertson, 1923). Strictly speaking, the
# term "autocatalytic" applied only to the accelerating phase of growth, but Robertson
# used it to refer to the whole S-curve as well,and this rather loose designation was
# repeated by others, with the result that the
# autocatalytic curve came to be synonymous
# with the logistic curve.

# %% [markdown]
# ### Reed and Pearl (1920) - Logistic rediscovered
# In 1920, Reed and Pearl [published](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1084522/pdf/pnas01915-0003.pdf) an article titled *On the rate of growth of the population of the united states since 1790 and its mathematical representation* in the journal named *Proceedings of the national achademy of sciences*.
#
# With this publication the pair are credited with independently rediscovering the Logistic curve originally published by Verhulst and then popularizing it within the west.

# %% [markdown]
# They make a similar argument for the characteristics that a population model must satisfy:
#
# > The following conditions should be fulfilled by any equation which is to
# describe adequately the growth of population in an area of fixed limits.
# > 1. Asymptotic to a line $y = k$ when $x=-\infty$ .
# > 2. Asymptotic to a line $y=0$ when $x = +\infty$
# > 3. A point of inflection at some point $x = \alpha$ and $y=\beta$.
# > 4. Concave upwards to left of $x = \alpha$  and concave downward to right of $x = \alpha$ .
# > 5. No horizontal slope except at $x=\pm \infty$
# > 6. Values of y varying continuously from 0 to k as x varies from $-\infty$ to $+\infty$
# In th

# %% [markdown]
# They propose the following equation which they argue satisfy these requirements if $a$, $b$, and $c$ have positive values.
#
# $$y = \frac{be^{ax}}{1+ce^{ax}}$$
#
# They also note that this function is equivalent to this simpler version which they refer to as the final form:
#
# $$y =\frac{b}{e^{-ax}+c}$$

# %% [markdown]
# **Note**: This form is also equivalent to the form commonly cited today, as well as several other similar forms, including Verhulst, due to the flexibility in terms of how we perform algebra and take the derivative/integral.
#
# $$y = \frac{K}{1+Ae^{-rt}}$$

# %% [markdown]
# They also note the derivative of the function as:
#
# $$\frac{dy}{dx}=\frac{ay(b-cy)}{b}$$
#
# **Note**: We can algebraically restate this derivative as in the form that is commonly cited today as:
#
# $$= \frac{ayb(1-\frac{cy}{b})}{b} $$
# $$= ay \big(1-\frac{cy}{b} \big)$$

# %% [markdown]
# ### Pearl and Reed (1923) - Further Generalization

# %% [markdown]
# [Kingsland (1982)](https://u.demog.berkeley.edu/~jrw/Biblio/Eprints/%20J-L/kingsland.1982_logistic.curve.pdf) states:
#
# > In the process of freeing the logistic from
# its restrictive symmetry, Pearl and Reed
# generalized their original equation by adding more terms to it. Thus the original equation could be written as follows (Pearl and
# Reed, 1923):
# > $$ N=\frac{K}{me^{aT}} $$
# >
# > where K, a, and m are constants. The generalized equation was then:
# >
# > $$ N= \frac{K}{1 + me^a_1t + a_2t^2 + ... + a_nt^n} $$
# >
# > The actual shape of the curve depended on
# the number of terms and the values of the
# constants. If all constants from $a_2$ to a, were
# zero, the curve would reduce to the original
# symmetrical form. If the terms up to $t_3$ only
# were left in, the curve would be asymmetrical and sigmoidal. Apart from the difficulty
# of determining so many constants, the problem with this generalization was that it could
# be made to fit almost any set of data, and
# was therefore "logistic" in name only. The
# whole purpose of identifying a "law" would
# have been defeated. Pearl was aware of this
# type of error, for he warned against it in a
# 1923 textbook on statistical methods written
# for medical students (Pearl, 1923, p. 333).
# But his enthusiasm for the logistic was such
# that he failed to perceive the aptness of his
# own warning, and believed that in the expanded equation he had succeeded in setting
# forth a "comprehensive general theory of
# population growth" (Pearl and Reed, 1923).
# > In fact, however, Pearl and Reed seldom had recourse to the generalized equation
# beyond the simple asymmetrical form, except as a final, if inadequate, rebuttal to criticisms that populations did not always follow
# a "logistic" curve.

# %% [markdown]
# ## Derevation

# %% [markdown]
# The logical derrevation, or thought process responsible for the derevation, of the logistic curve is described below. This section focuses more on the logical progression to mathematically construct the equation and not necessarrily performing the mathematical proofs to integrate/differentiate equations. That being said, the following references helped me understand those proofs in their various notations:

# %% [markdown]
# - [stackexchange](https://stats.stackexchange.com/questions/459166/where-does-the-logistic-function-come-from)
# - [Bacaer 2011](https://webpages.ciencias.ulisboa.pt/~mcgomes/aulas/dinpop/Mod13/Verhulst.pdf)
# - [Delmas 2005](https://journals.openedition.org/msh/2893?file=1)
# - [Deakin (2018)](http://www.mygeodesy.id.au/documents/The%20Logistic%20Function.pdf)
# - [wikipedia](https://en.wikipedia.org/wiki/Pierre_Fran%C3%A7ois_Verhulst)
# - [Northwestern University](https://mlerma54.github.io/courses/math214-2-03f/notes/c2-logist.pdf)
# - [Clark University](https://www2.clarku.edu/faculty/djoyce/ma121/logistic.pdf)

# %% [markdown]
# The general through process put forward by Verhulst was that we start with progressive growth rates until we get to exponential, then we need to put downward pressure on the unrestrained exponential growth rate; when that downward pressure takes a specific form, we reach the logistic equation.

# %% [markdown]
# ### Constant Growth

# %% [markdown]
# If a population is growing at a constant rate, the derivative of that growth function is a constant
#
# $$y = mx+b,$$
# $$ \frac{dy}{dx}=m$$

# %% [markdown]
# ### Geometric Growth

# %% [markdown]
# If a population grows at a constant proportion or percentage, i.e. a geometric rate, the population will grow by the same percentage each time period. The derivative of that growth function is not constant, but is instead proportional to the length of time. Each full time interval, the population is multiplied a given number of times coresponding to that time interval.
#
# $$y = a(1 + r)^t,$$
# $$ \frac{dy}{dt}= a(1 + r)^t \ ln(1+r) $$
#
# And we can see this porportionality in the simplification of the derivative above.
#
# $$ = y \ ln(1+r)$$
#
# $$ = y \beta$$

# %% [markdown]
# Becasue of this, the geometric function is discrete as the time intervals are a finite and fixed length. If we think about continous or instantaneous growth, we are thinking about exponential growth.

# %% [markdown]
# ### Exponential Growth

# %% [markdown]
# Exponential growth is modeled using the exponential function. This function usually takes the form:
#
# $$y = ae^{rt},$$
# $$\frac{dy}{dt}=rae^{rt}=ry$$
#
# Where $a$ is a starting point or initial population.

# %% [markdown]
# **Note**: I had come confusion as to why $e$ is generally selected as the base for the exponential function. To understand this, we need to work our way in reverse; we start thinking about the rate of change (i.e. what the derivative equals), we then integrate the derivative to get a solution for the equation. It just to happens that algebraically, the solution will always involve raising $e$ to some power. A proof can be found on this [stackexchange](https://math.stackexchange.com/questions/1350855/why-do-we-use-base-e-in-population-growth-questions).

# %% [markdown]
# As noted [here](https://www2.clarku.edu/faculty/djoyce/ma121/logistic.pdf), we can algebraically manipulate the exponential equation so that the base is something other than $e$. In order to do so, we must make a few adjustments:
#
# $$y = Ab^{\frac{rt}{ln(b)}}$$
#
# And we can simplify the equation with $s=\frac{r}{ln(b)}$ such that the equation becomes:
#
# $$y = Ab^{st}$$
#
# $$\frac{dy}{dt}=ln(b)sAb^{st} =ln(b)sy = ry$$

# %% [markdown]
# **Note**: We again see the proportionality in the equation above.

# %% [markdown]
# ### Restricted Exponential Growth

# %% [markdown]
# You start with exponential growth
#
# $$\frac{dy}{dt} = r y$$

# %% [markdown]
# Then add a downward pressure which is dependent on the population.
#
# We can do this in one of two ways:
#
# First, by subtracting some variable from our exponential growth rate:
#
# $$\frac{dy}{dt} = r y - \phi(y)$$

# %% [markdown]
# Or second we can multiply our original growth rate by some decreasing fucntion $g(y)$ so that the growth rate is again proportional to the population while having a downward pressure.
#
# $$\frac{dy}{dt} = r y \ g(y)$$

# %% [markdown]
# In either case, in order for the function to take on the requisite characteristics to become a logistic function, we would need to restrict these decay functions such that $\phi(y)= ny^2$ and $n=\frac{r}{k}$
#
# $$\frac{dy}{dt} = r y - ny^2$$
#
# $$ \frac{dy}{dt}=r y \big(1 - \frac{y}{k} \big)$$

# %% [markdown]
# ## Properties
# Below is a list of notable properties which might implicate the use of this function for various applications.

# %% [markdown]
# - Monotonic
# - Constrained between two horixontal asymtotes
# - Convex until a specific point and then concave
# - Demonstrates rotational symmetry at a specific point
# - First Derivative is bell shaped

# %% [markdown]
# ## Special Cases

# %% [markdown]
# ### Standard Logistic Function

# %% [markdown]
# A variation of the general equation such that all the constants are equal to one produces the standard logistic function.
# $$f(x) = \frac{1}{1+e^{-x}} = \frac{e^{x}}{1+e^{x}} = 1 - f(-x)$$
#
# The range of this function is limited to the interval of $(0, 1)$. As we will see, this gives it a connection to probability distibutions.

# %% [markdown]
# ## Connections

# %% [markdown]
# ### Logistic Regression
# Cox is credited ([example](https://stats.stackexchange.com/questions/192948/why-is-the-logistic-distribution-called-logistic)) with coining the term in 1958 with his [publication](https://rss.onlinelibrary.wiley.com/doi/10.1111/j.2517-6161.1958.tb00292.x) of *The Regression Analysis of Binary Sequences*.
#
# The method allows a data scientist to fit the logistic function to a data set using a linear regression and associated calibration techniques.

# %% [markdown]
# ### Logit Function

# %% [markdown]
# ### Probability Distributions

# %% [markdown]
# There is a strong connection between standardized sigmoids (like the standard logistic function) and probability distributions. Many cumulative density functions (CDFs) are standardized sigmoidal functions. Additionally, the drivatie of a sigmoid is a bell shaped curve; thus all bell shaped probability density functions (PDFs) have sigmoidal CDFs.

# %% [markdown]
# #### Normal Distribution

# %% [markdown]
# As [Cramer (2002)](https://papers.tinbergen.nl/02119.pdf) notes,
#
# > Over a fairly wide central range, for values of P from 3. to .7, the logistic curve closely resembles in shape as the normal probability distribution. The two functions ... both pass through the point (0,.5) and they can be made almost to conincide upon a suitable adjustment of (the function parameters).
#
# He notes however that this is sheer algebraic coincidence and there appears to be no intrinsic relation between the two forms.

# %% [markdown]
# A [post](https://www.quora.com/What-is-the-difference-between-a-logistic-distribution-and-a-Gaussian-distribution-not-by-equations-but-by-characteristics) adds:
#
# > The logistic distribution has just slightly heavier tails. It’s not quite as heavy-tailed as any t-distribution (i.e., all of its moments exist), so you can think of it as a nice middle ground between the two.

# %% [markdown]
# An article on fitting the logistic to the normal distribution can be found [here](https://www.johndcook.com/blog/2010/05/18/normal-approximation-to-logistic/).

# %% [markdown]
# Additionally, as this [article](https://stats.stackexchange.com/questions/389896/is-there-a-connection-between-the-normal-and-the-logistic-distribution) notes, the logistic function can be used in Bayesian calculations when dealing with two normal random variables.
